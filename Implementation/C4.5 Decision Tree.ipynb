# %%
import numpy as np
import pandas as pd
from math import log2

# %%
data = pd.read_csv("../data/agaricus-lepiota.csv")
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises? odor gill-attachment  \
# 0     p         x           s         n        t    p               f
# 1     e         x           s         y        t    a               f
# 2     e         b           s         w        t    l               f
# 3     p         x           y         w        t    p               f
# 4     e         x           s         g        f    n               f
#
#   gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
trainingSample = data.sample(frac=0.70)
display(trainingSample)
trainingIndexes = trainingSample.index.values
testingSample = data.drop(trainingIndexes)
display(testingSample)
# Out:
#      class cap-shape cap-surface cap-color bruises? odor gill-attachment  \
# 4322     p         x           f         y        f    f               f
# 7788     e         f           s         n        f    n               a
# 7355     p         f           y         n        f    s               f
# 7567     p         k           s         n        f    s               f
# 759      e         x           y         n        t    a               f
# 6813     p         f           s         e        f    y               f
# 6307     p         f           y         n        f    f               f
# 1099     p         x           y         n        t    p               f
# 1597     e         x           s         g        f    n               f
# 1384     e         f           s         g        f    n               f
# 1724     e         b           y         y        t    a               f
# 5033     p         x           y         g        f    f               f
# 1518     e         b           y         y        t    a               f
# 5796     p         f           y         y        f    f               f
# 2881     e         x           s         w        f    n               f
# 3388     p         x           s         w        f    c               f
# 3312     e         f           y         e        t    n               f
# 153      e         s           f         n        f    n               f
# 4873     p         f           y         g        f    f               f
# 6076     p         f           s         n        f    y               f
# 309      e         x           f         w        f    n               f
# 4571     p         x           y         y        f    f               f
# 4506     p         f           y         g        f    f               f
# 3602     e         x           y         g        t    n               f
# 2780     e         f           f         n        t    n               f
# 6730     p         x           s         e        f    f               f
# 1389     e         x           f         n        f    n               f
# 6368     p         f           s         n        f    f               f
# 5786     p         x           y         g        f    f               f
# 2636     e         x           y         g        t    n               f
# ...    ...       ...         ...       ...      ...  ...             ...
# 7992     p         k           y         n        f    f               f
# 8089     p         k           y         e        f    f               f
# 5591     p         f           s         g        t    f               f
# 6327     p         x           s         e        f    y               f
# 3114     e         f           f         g        t    n               f
# 1923     e         x           f         g        f    n               f
# 639      e         x           y         w        t    a               f
# 4320     p         f           y         y        f    f               f
# 3120     e         f           f         g        t    n               f
# 2654     e         x           y         g        t    n               f
# 501      e         b           y         y        t    a               f
# 1361     p         f           y         n        t    p               f
# 983      e         x           f         n        f    n               f
# 266      e         f           s         g        f    n               f
# 1190     e         x           f         w        f    n               f
# 5425     p         f           s         g        t    f               f
# 7820     p         k           y         e        f    m               f
# 3009     p         x           f         g        f    f               f
# 3564     e         x           y         n        t    n               f
# 2270     e         f           f         g        t    n               f
# 4566     p         x           y         g        f    f               f
# 7368     p         x           y         c        f    m               a
# 4475     p         x           y         y        f    f               f
# 984      p         x           s         w        t    p               f
# 2948     e         x           y         e        t    n               f
# 4204     p         f           y         g        f    f               f
# 2149     p         x           s         w        t    p               f
# 522      e         f           y         y        t    a               f
# 4572     p         f           f         g        f    f               f
# 3352     p         x           f         g        f    f               f
#
#      gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 4322            c         b          g   ...                          k
# 7788            c         b          o   ...                          s
# 7355            c         n          b   ...                          k
# 7567            c         n          b   ...                          k
# 759             c         b          n   ...                          y
# 6813            c         n          b   ...                          k
# 6307            c         n          b   ...                          k
# 1099            c         n          n   ...                          s
# 1597            w         b          p   ...                          s
# 1384            w         b          h   ...                          f
# 1724            c         b          g   ...                          s
# 5033            c         b          g   ...                          k
# 1518            c         b          g   ...                          s
# 5796            c         b          h   ...                          k
# 2881            w         b          k   ...                          f
# 3388            w         n          n   ...                          s
# 3312            c         b          u   ...                          s
# 153             c         n          k   ...                          s
# 4873            c         b          g   ...                          k
# 6076            c         n          b   ...                          k
# 309             w         b          n   ...                          s
# 4571            c         b          h   ...                          k
# 4506            c         b          g   ...                          k
# 3602            c         b          p   ...                          s
# 2780            c         b          u   ...                          s
# 6730            c         n          b   ...                          s
# 1389            w         b          k   ...                          f
# 6368            c         n          b   ...                          s
# 5786            c         b          h   ...                          k
# 2636            c         b          n   ...                          s
# ...           ...       ...        ...   ...                        ...
# 7992            c         n          b   ...                          k
# 8089            c         n          b   ...                          k
# 5591            c         b          w   ...                          f
# 6327            c         n          b   ...                          s
# 3114            c         b          w   ...                          s
# 1923            w         b          h   ...                          f
# 639             c         b          g   ...                          s
# 4320            c         b          h   ...                          k
# 3120            c         b          u   ...                          s
# 2654            c         b          p   ...                          s
# 501             c         b          g   ...                          s
# 1361            c         n          w   ...                          s
# 983             w         b          k   ...                          s
# 266             w         b          p   ...                          s
# 1190            w         b          p   ...                          f
# 5425            c         b          w   ...                          s
# 7820            c         b          w   ...                          y
# 3009            c         b          h   ...                          k
# 3564            c         b          w   ...                          s
# 2270            c         b          n   ...                          s
# 4566            c         b          g   ...                          k
# 7368            c         b          w   ...                          y
# 4475            c         b          h   ...                          k
# 984             c         n          n   ...                          s
# 2948            c         b          n   ...                          s
# 4204            c         b          h   ...                          k
# 2149            c         n          w   ...                          s
# 522             c         b          p   ...                          y
# 4572            c         b          g   ...                          k
# 3352            c         b          h   ...                          k
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 4322                      b                      p         p          w
# 7788                      o                      o         p          o
# 7355                      p                      w         p          w
# 7567                      p                      p         p          w
# 759                       w                      w         p          w
# 6813                      w                      w         p          w
# 6307                      w                      w         p          w
# 1099                      w                      w         p          w
# 1597                      w                      w         p          w
# 1384                      w                      w         p          w
# 1724                      w                      w         p          w
# 5033                      n                      b         p          w
# 1518                      w                      w         p          w
# 5796                      p                      b         p          w
# 2881                      w                      w         p          w
# 3388                      w                      w         p          w
# 3312                      w                      g         p          w
# 153                       w                      w         p          w
# 4873                      p                      b         p          w
# 6076                      w                      p         p          w
# 309                       w                      w         p          w
# 4571                      p                      p         p          w
# 4506                      p                      p         p          w
# 3602                      p                      w         p          w
# 2780                      g                      p         p          w
# 6730                      w                      w         p          w
# 1389                      w                      w         p          w
# 6368                      w                      p         p          w
# 5786                      b                      b         p          w
# 2636                      p                      g         p          w
# ...                     ...                    ...       ...        ...
# 7992                      w                      w         p          w
# 8089                      w                      p         p          w
# 5591                      w                      w         p          w
# 6327                      p                      p         p          w
# 3114                      p                      p         p          w
# 1923                      w                      w         p          w
# 639                       w                      w         p          w
# 4320                      p                      p         p          w
# 3120                      p                      g         p          w
# 2654                      p                      g         p          w
# 501                       w                      w         p          w
# 1361                      w                      w         p          w
# 983                       w                      w         p          w
# 266                       w                      w         p          w
# 1190                      w                      w         p          w
# 5425                      w                      w         p          w
# 7820                      c                      c         p          w
# 3009                      p                      p         p          w
# 3564                      g                      w         p          w
# 2270                      p                      w         p          w
# 4566                      p                      n         p          w
# 7368                      c                      c         p          w
# 4475                      n                      b         p          w
# 984                       w                      w         p          w
# 2948                      p                      g         p          w
# 4204                      b                      p         p          w
# 2149                      w                      w         p          w
# 522                       w                      w         p          w
# 4572                      n                      b         p          w
# 3352                      p                      n         p          w
#
#      ring-number ring-type spore-print-color population habitat
# 4322           o         l                 h          y       p
# 7788           o         p                 y          c       l
# 7355           o         e                 w          v       l
# 7567           o         e                 w          v       l
# 759            o         p                 k          y       p
# 6813           o         e                 w          v       p
# 6307           o         e                 w          v       l
# 1099           o         p                 n          s       g
# 1597           o         e                 k          a       g
# 1384           o         e                 k          a       g
# 1724           o         p                 n          n       m
# 5033           o         l                 h          v       g
# 1518           o         p                 k          s       g
# 5796           o         l                 h          v       p
# 2881           o         e                 k          s       g
# 3388           o         p                 n          v       d
# 3312           o         p                 n          v       d
# 153            o         p                 k          v       u
# 4873           o         l                 h          y       g
# 6076           o         e                 w          v       l
# 309            o         e                 n          s       g
# 4571           o         l                 h          y       d
# 4506           o         l                 h          y       d
# 3602           o         p                 k          y       d
# 2780           o         p                 k          y       d
# 6730           o         e                 w          v       l
# 1389           o         e                 n          s       g
# 6368           o         e                 w          v       d
# 5786           o         l                 h          v       g
# 2636           o         p                 n          y       d
# ...          ...       ...               ...        ...     ...
# 7992           o         e                 w          v       l
# 8089           o         e                 w          v       d
# 5591           o         p                 h          v       g
# 6327           o         e                 w          v       l
# 3114           o         p                 n          v       d
# 1923           o         e                 n          s       g
# 639            o         p                 k          s       m
# 4320           o         l                 h          v       g
# 3120           o         p                 k          y       d
# 2654           o         p                 k          v       d
# 501            o         p                 k          n       g
# 1361           o         p                 k          v       u
# 983            o         e                 n          s       g
# 266            o         e                 k          a       g
# 1190           o         e                 k          s       g
# 5425           o         p                 h          s       g
# 7820           n         n                 w          c       d
# 3009           o         l                 h          y       p
# 3564           o         p                 n          y       d
# 2270           o         p                 n          v       d
# 4566           o         l                 h          y       p
# 7368           n         n                 w          c       d
# 4475           o         l                 h          y       g
# 984            o         p                 k          s       u
# 2948           o         p                 n          v       d
# 4204           o         l                 h          y       p
# 2149           o         p                 k          s       g
# 522            o         p                 n          y       p
# 4572           o         l                 h          v       d
# 3352           o         l                 h          v       g
#
# [5687 rows x 23 columns]
#      class cap-shape cap-surface cap-color bruises? odor gill-attachment  \
# 0        p         x           s         n        t    p               f
# 12       e         b           s         y        t    a               f
# 16       e         f           f         w        f    n               f
# 18       p         x           y         w        t    p               f
# 30       e         b           s         y        t    l               f
# 37       p         x           y         n        t    p               f
# 38       e         x           f         y        t    a               f
# 39       e         b           s         y        t    l               f
# 42       e         x           f         n        f    n               f
# 49       e         f           y         y        t    l               f
# 51       e         x           s         w        t    l               f
# 52       e         b           s         w        t    l               f
# 55       e         b           y         y        t    a               f
# 58       e         x           s         y        t    l               f
# 62       e         b           s         y        t    l               f
# 68       e         x           y         y        t    a               f
# 70       e         f           f         y        t    l               f
# 71       e         b           y         w        t    l               f
# 72       e         f           f         y        t    l               f
# 74       e         b           s         y        t    a               f
# 76       e         x           s         w        t    l               f
# 77       e         f           y         n        t    l               f
# 79       e         f           y         n        t    a               f
# 80       e         x           s         n        f    n               f
# 81       p         x           y         w        t    p               f
# 84       e         x           y         y        t    l               f
# 85       e         x           s         n        f    n               f
# 88       e         f           y         n        t    l               f
# 90       e         x           f         n        f    n               f
# 92       e         x           y         y        t    a               f
# ...    ...       ...         ...       ...      ...  ...             ...
# 8017     e         b           f         w        f    n               f
# 8018     e         x           s         w        f    n               f
# 8021     p         f           s         n        f    y               f
# 8024     p         k           y         n        f    f               f
# 8031     p         k           y         e        f    f               f
# 8033     p         k           y         n        f    f               f
# 8040     e         b           s         n        f    n               a
# 8041     p         k           y         e        f    y               f
# 8043     e         f           s         n        f    n               a
# 8044     e         f           s         n        f    n               a
# 8048     p         k           s         n        f    y               f
# 8049     p         k           y         n        f    f               f
# 8051     e         x           f         w        f    n               f
# 8059     p         k           s         n        f    f               f
# 8067     e         b           s         n        f    n               a
# 8069     e         k           s         n        f    n               a
# 8072     p         k           y         e        f    f               f
# 8075     e         f           s         n        f    n               a
# 8078     e         b           f         g        f    n               f
# 8080     p         k           s         n        f    s               f
# 8082     p         k           s         e        f    s               f
# 8084     e         b           f         g        f    n               f
# 8085     e         k           f         w        f    n               f
# 8093     p         x           s         n        f    y               f
# 8098     p         k           s         e        f    y               f
# 8104     e         k           s         n        f    n               a
# 8109     e         b           s         w        f    n               f
# 8116     p         k           y         n        f    s               f
# 8118     p         k           y         n        f    f               f
# 8121     e         f           s         n        f    n               a
#
#      gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0               c         n          k   ...                          s
# 12              c         b          w   ...                          s
# 16              w         b          k   ...                          s
# 18              c         n          n   ...                          s
# 30              c         b          g   ...                          s
# 37              c         n          w   ...                          s
# 38              w         n          p   ...                          s
# 39              c         b          k   ...                          s
# 42              c         n          g   ...                          s
# 49              c         b          w   ...                          y
# 51              c         b          k   ...                          s
# 52              c         b          k   ...                          s
# 55              c         b          w   ...                          s
# 58              c         b          k   ...                          s
# 62              c         b          g   ...                          s
# 68              c         b          w   ...                          s
# 70              w         n          p   ...                          s
# 71              c         b          g   ...                          s
# 72              w         n          w   ...                          s
# 74              c         b          k   ...                          s
# 76              w         n          n   ...                          s
# 77              c         b          p   ...                          y
# 79              c         b          n   ...                          y
# 80              w         b          k   ...                          s
# 81              c         n          w   ...                          s
# 84              c         b          w   ...                          y
# 85              w         b          k   ...                          s
# 88              c         b          w   ...                          y
# 90              c         n          n   ...                          s
# 92              c         b          g   ...                          s
# ...           ...       ...        ...   ...                        ...
# 8017            w         b          g   ...                          k
# 8018            w         b          w   ...                          k
# 8021            c         n          b   ...                          s
# 8024            c         n          b   ...                          s
# 8031            c         n          b   ...                          k
# 8033            c         n          b   ...                          s
# 8040            c         b          n   ...                          s
# 8041            c         n          b   ...                          s
# 8043            c         b          n   ...                          s
# 8044            c         b          n   ...                          s
# 8048            c         n          b   ...                          k
# 8049            c         n          b   ...                          s
# 8051            w         b          w   ...                          k
# 8059            c         n          b   ...                          s
# 8067            c         b          n   ...                          s
# 8069            c         b          n   ...                          s
# 8072            c         n          b   ...                          k
# 8075            c         b          o   ...                          s
# 8078            w         b          g   ...                          s
# 8080            c         n          b   ...                          k
# 8082            c         n          b   ...                          k
# 8084            w         b          p   ...                          k
# 8085            w         b          g   ...                          k
# 8093            c         n          b   ...                          k
# 8098            c         n          b   ...                          k
# 8104            c         b          y   ...                          s
# 8109            w         b          w   ...                          s
# 8116            c         n          b   ...                          k
# 8118            c         n          b   ...                          s
# 8121            c         b          n   ...                          s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 12                        w                      w         p          w
# 16                        w                      w         p          w
# 18                        w                      w         p          w
# 30                        w                      w         p          w
# 37                        w                      w         p          w
# 38                        w                      w         p          w
# 39                        w                      w         p          w
# 42                        w                      w         p          w
# 49                        w                      w         p          w
# 51                        w                      w         p          w
# 52                        w                      w         p          w
# 55                        w                      w         p          w
# 58                        w                      w         p          w
# 62                        w                      w         p          w
# 68                        w                      w         p          w
# 70                        w                      w         p          w
# 71                        w                      w         p          w
# 72                        w                      w         p          w
# 74                        w                      w         p          w
# 76                        w                      w         p          w
# 77                        w                      w         p          w
# 79                        w                      w         p          w
# 80                        w                      w         p          w
# 81                        w                      w         p          w
# 84                        w                      w         p          w
# 85                        w                      w         p          w
# 88                        w                      w         p          w
# 90                        w                      w         p          w
# 92                        w                      w         p          w
# ...                     ...                    ...       ...        ...
# 8017                      w                      w         p          w
# 8018                      w                      w         p          w
# 8021                      p                      w         p          w
# 8024                      p                      p         p          w
# 8031                      p                      p         p          w
# 8033                      p                      w         p          w
# 8040                      o                      o         p          o
# 8041                      p                      w         p          w
# 8043                      o                      o         p          n
# 8044                      o                      o         p          n
# 8048                      w                      p         p          w
# 8049                      w                      w         p          w
# 8051                      w                      w         p          w
# 8059                      w                      p         p          w
# 8067                      o                      o         p          o
# 8069                      o                      o         p          n
# 8072                      w                      w         p          w
# 8075                      o                      o         p          o
# 8078                      w                      w         p          w
# 8080                      p                      w         p          w
# 8082                      p                      p         p          w
# 8084                      w                      w         p          w
# 8085                      w                      w         p          w
# 8093                      w                      w         p          w
# 8098                      w                      p         p          w
# 8104                      o                      o         p          o
# 8109                      w                      w         p          w
# 8116                      p                      w         p          w
# 8118                      p                      w         p          w
# 8121                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 k          s       u
# 12             o         p                 n          s       g
# 16             o         e                 n          a       g
# 18             o         p                 n          s       u
# 30             o         p                 n          n       m
# 37             o         p                 n          s       u
# 38             o         p                 n          v       d
# 39             o         p                 k          s       m
# 42             o         p                 k          y       u
# 49             o         p                 k          s       p
# 51             o         p                 k          s       g
# 52             o         p                 n          n       m
# 55             o         p                 k          s       m
# 58             o         p                 k          n       g
# 62             o         p                 n          s       m
# 68             o         p                 k          n       g
# 70             o         p                 n          v       d
# 71             o         p                 n          s       m
# 72             o         p                 n          v       d
# 74             o         p                 k          s       g
# 76             o         p                 u          v       d
# 77             o         p                 n          y       p
# 79             o         p                 n          y       g
# 80             o         e                 n          s       g
# 81             o         p                 k          s       g
# 84             o         p                 k          s       g
# 85             o         e                 k          s       g
# 88             o         p                 k          y       g
# 90             o         p                 n          y       u
# 92             o         p                 k          s       g
# ...          ...       ...               ...        ...     ...
# 8017           t         p                 w          n       g
# 8018           t         p                 w          s       g
# 8021           o         e                 w          v       l
# 8024           o         e                 w          v       d
# 8031           o         e                 w          v       p
# 8033           o         e                 w          v       l
# 8040           o         p                 y          v       l
# 8041           o         e                 w          v       p
# 8043           o         p                 b          v       l
# 8044           o         p                 y          c       l
# 8048           o         e                 w          v       d
# 8049           o         e                 w          v       l
# 8051           t         p                 w          s       g
# 8059           o         e                 w          v       p
# 8067           o         p                 b          c       l
# 8069           o         p                 n          c       l
# 8072           o         e                 w          v       p
# 8075           o         p                 o          c       l
# 8078           t         p                 w          s       g
# 8080           o         e                 w          v       d
# 8082           o         e                 w          v       p
# 8084           t         p                 w          s       g
# 8085           t         p                 w          s       g
# 8093           o         e                 w          v       d
# 8098           o         e                 w          v       d
# 8104           o         p                 n          v       l
# 8109           t         p                 w          n       g
# 8116           o         e                 w          v       l
# 8118           o         e                 w          v       d
# 8121           o         p                 b          c       l
#
# [2437 rows x 23 columns]

# %%
def entropy(x):
    result = 0
    unique = list(set(x))
    for i in unique:
        p = x.count(i)/len(x)
        result += -(p)*log2(p)
    return result

# %%
results = [False, False, True, True, True, False, True, False, True, True, True, True, True, False]
entropy(results)
# Out:
# 0.9402859586706311

# %%
def gain(classification, x):
    zipped = list(zip(classification, x))
    result = entropy(classification)
    unique = list(set(x))
    for i in unique:
        sublist = [y for y in zipped if y[1]==i]
        p = x.count(i)/len(x)
        result += -(p)*entropy(sublist)
    return result

# %%
weak = "Weak"
strong = "Strong"
wind = [weak, strong, weak, weak, weak, strong, strong, weak, weak, weak, strong, strong, weak, strong]
gain(results, wind)
# Out:
# 0.04812703040826949

# %%
def splitInfo(classification, x):
    result = 0
    unique = list(set(x))
    for i in unique:
        p = x.count(i)/len(x)
        result += -(p)*log2(p)
    return result

# %%
splitInfo(results, wind)
# Out:
# 0.9852281360342515

# %%
def gainRatio(classification, x):
    if (gain(classification, x) == 0) or (splitInfo(classification, x) == 0):
        return 0
    else:
        return gain(classification, x) / splitInfo(classification, x)

# %%
gainRatio(results, wind)
# Out:
# 0.048848615511520824

# %%
sunny = "Sunny"
overcast = "Overcast"
rain = "Rain"
outlook = [sunny, sunny, overcast, rain, rain, rain, overcast, sunny, sunny, rain, sunny, overcast, overcast, rain]
gainRatio(results, outlook)
# Out:
# 0.15642756242117528

# %%
class Tree:
    def __init__(self, df):
        self.dfFull = df
        self.results = list(df['class'])
        self.df = df.drop(columns=['class'])
        self.best = self.bestAttr()
        self.total = ""
        if self.best == "":
            self.nodes = {}
            self.total = str(list(set(list(self.dfFull['class'])))[0])
            return
        bestCol = list(df[self.best])
        bestColValues = list(set(bestCol))
        self.nodes = dict.fromkeys(bestColValues)
        self.buildNodes()
            
    def buildNodes(self):
         for i in self.nodes:
            qr = (str(self.best) + " == " + str(i))
            dfSplit = self.dfFull.loc[self.dfFull[self.best] == i]
            self.nodes[i] = Tree(dfSplit)
        
    def bestAttr(self):
        maxGain = 0
        whoIsMaxGain = ""
        for i in self.df.columns:
            gain = gainRatio(self.results, list(self.df[i]))
            if gain > maxGain:
                maxGain = gain
                whoIsMaxGain = i
        return whoIsMaxGain
    
    def getClassification(self, x):
        if self.best != "":
            return self.nodes[x[self.best]].getClassification(x)
        else:
            return self.total
    
    def __str__(self, level=0):
        ret = "\t"*level+(self.best)+"\n"
        for child in self.nodes:
            ret += "\t"*level+child + ": " + self.total + self.nodes[child].total + self.nodes[child].__str__(level+1)
        return ret

# %%
decisionTree = Tree(trainingSample)

print("FOR DEVELOPER TEST ONLY, FORMATTING IS NOT WORKING CORRECTLY")
print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
print(decisionTree)
print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
print("FOR DEVELOPER TEST ONLY, FORMATTING IS NOT WORKING CORRECTLY")
# Out:
# FOR DEVELOPER TEST ONLY, FORMATTING IS NOT WORKING CORRECTLY
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# odor
# f: p
# a: e
# l: e
# p: p
# s: p
# m: p
# y: p
# c: p
# n: 	spore-print-color
# 	w: 		veil-color
# 		y: p
# 		w: 			gill-size
# 			n: 				gill-spacing
# 				c: p
# 				w: 					bruises?
# 					f: e
# 					t: p
# 			b: e
# 	k: e
# 	b: e
# 	h: e
# 	y: e
# 	o: e
# 	r: p
# 	n: e
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# FOR DEVELOPER TEST ONLY, FORMATTING IS NOT WORKING CORRECTLY

# %%
predictions = []
for i in testingSample.index.values:
    predictions.append(tuple([testingSample.loc[i]['class'], decisionTree.getClassification(testingSample.loc[i])]))
print(predictions)
# Out:
# [('p', 'p'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('p', 'p'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('p', 'p'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e ...

# %%
def hit(x):
    if x[0] == x[1]:
        return True
    else:
        return False

# %%
hits = list(filter(hit, predictions))

numPredictions = len(predictions)
numHits = len(hits)

performance = numHits/numPredictions

# %%
print("Correctly Classified Rows: " + str(performance*100) + "%")
print("Incorrectly Classified Rows: " + str(100-(performance*100)) + "%")
# Out:
# Correctly Classified Rows: 100.0%
# Incorrectly Classified Rows: 0.0%
