# %%
import numpy as np
import pandas as pd
from math import log2

# %%
data = pd.read_csv("../data/agaricus-lepiota.csv")
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises? odor gill-attachment  \
# 0     p         x           s         n        t    p               f
# 1     e         x           s         y        t    a               f
# 2     e         b           s         w        t    l               f
# 3     p         x           y         w        t    p               f
# 4     e         x           s         g        f    n               f
#
#   gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
trainingSample = data.sample(frac=0.70)
display(trainingSample)
trainingIndexes = trainingSample.index.values
testingSample = data.drop(trainingIndexes)
display(testingSample)
# Out:
#      class cap-shape cap-surface cap-color bruises? odor gill-attachment  \
# 771      e         b           s         y        t    l               f
# 2889     e         x           y         g        t    n               f
# 5089     p         f           y         y        f    f               f
# 4729     p         f           f         y        f    f               f
# 7396     p         k           s         e        f    s               f
# 7343     p         k           y         n        f    s               f
# 3221     e         f           y         g        t    n               f
# 2697     p         x           f         g        f    f               f
# 2360     e         x           y         n        t    n               f
# 3780     e         f           y         g        t    n               f
# 4816     p         f           f         y        f    f               f
# 4849     p         f           y         g        f    f               f
# 4329     p         x           y         n        f    s               f
# 378      e         x           y         y        t    l               f
# 1595     e         f           f         g        f    n               f
# 5643     p         f           y         y        f    f               f
# 6222     p         k           s         e        f    f               f
# 6172     p         f           s         e        f    f               f
# 722      e         f           s         y        t    l               f
# 3479     p         x           f         g        f    f               f
# 1008     e         x           f         n        f    n               f
# 6982     p         k           s         e        f    s               f
# 5502     e         k           y         e        t    n               f
# 3241     e         f           y         g        t    n               f
# 7026     e         x           s         n        f    n               a
# 6393     p         f           y         n        f    y               f
# 6907     e         x           f         g        f    n               f
# 3193     p         f           f         y        f    f               f
# 3418     p         x           s         g        f    c               f
# 3563     e         f           y         g        t    n               f
# ...    ...       ...         ...       ...      ...  ...             ...
# 2297     e         x           f         n        f    n               f
# 6245     p         f           y         e        f    f               f
# 4968     p         f           y         g        f    f               f
# 4061     e         f           f         n        t    n               f
# 2560     p         x           f         w        f    c               f
# 3721     e         f           y         n        t    n               f
# 4863     p         f           f         y        f    f               f
# 6178     p         x           y         e        f    s               f
# 4424     e         f           f         e        t    n               f
# 7372     e         k           s         g        f    n               f
# 4815     p         f           f         g        f    f               f
# 2708     e         x           y         n        t    n               f
# 2802     e         x           f         g        t    n               f
# 3901     p         x           y         y        f    f               f
# 7012     p         k           s         e        f    s               f
# 6118     p         x           s         e        f    f               f
# 3396     e         f           f         e        t    n               f
# 2964     e         x           y         n        t    n               f
# 4541     p         f           y         g        f    f               f
# 6        e         b           s         w        t    a               f
# 7649     e         b           s         w        f    n               f
# 2156     e         x           y         n        t    n               f
# 1236     e         f           s         g        f    n               f
# 651      e         b           s         y        t    l               f
# 6991     p         k           y         e        f    m               f
# 2451     e         x           y         g        t    n               f
# 3769     e         f           f         g        t    n               f
# 195      e         f           f         g        f    n               f
# 4150     e         f           y         e        t    n               f
# 5965     p         f           y         g        f    f               f
#
#      gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 771             c         b          k   ...                          s
# 2889            c         b          w   ...                          s
# 5089            c         b          h   ...                          k
# 4729            c         b          h   ...                          k
# 7396            c         n          b   ...                          k
# 7343            c         n          b   ...                          k
# 3221            c         b          n   ...                          s
# 2697            c         b          h   ...                          k
# 2360            c         b          n   ...                          s
# 3780            c         b          w   ...                          s
# 4816            c         b          h   ...                          k
# 4849            c         b          h   ...                          k
# 4329            c         n          b   ...                          s
# 378             c         b          k   ...                          s
# 1595            w         b          k   ...                          f
# 5643            c         b          g   ...                          k
# 6222            c         n          b   ...                          k
# 6172            c         n          b   ...                          s
# 722             w         n          w   ...                          s
# 3479            c         b          h   ...                          k
# 1008            w         b          k   ...                          s
# 6982            c         n          b   ...                          s
# 5502            c         b          e   ...                          s
# 3241            c         b          n   ...                          s
# 7026            c         b          n   ...                          s
# 6393            c         n          b   ...                          s
# 6907            w         b          g   ...                          k
# 3193            c         b          p   ...                          k
# 3418            c         n          p   ...                          s
# 3563            c         b          w   ...                          s
# ...           ...       ...        ...   ...                        ...
# 2297            w         b          p   ...                          f
# 6245            c         n          b   ...                          s
# 4968            c         b          p   ...                          k
# 4061            c         b          n   ...                          s
# 2560            c         n          g   ...                          s
# 3721            c         b          p   ...                          s
# 4863            c         b          p   ...                          k
# 6178            c         n          b   ...                          s
# 4424            c         b          n   ...                          s
# 7372            w         b          g   ...                          k
# 4815            c         b          g   ...                          k
# 2708            c         b          n   ...                          s
# 2802            c         b          n   ...                          s
# 3901            c         b          h   ...                          k
# 7012            c         n          b   ...                          s
# 6118            c         n          b   ...                          s
# 3396            c         b          n   ...                          s
# 2964            c         b          u   ...                          s
# 4541            c         b          p   ...                          k
# 6               c         b          g   ...                          s
# 7649            w         b          p   ...                          s
# 2156            c         b          n   ...                          s
# 1236            w         b          p   ...                          s
# 651             c         b          n   ...                          s
# 6991            c         b          y   ...                          y
# 2451            c         b          w   ...                          s
# 3769            c         b          w   ...                          s
# 195             c         n          g   ...                          s
# 4150            c         b          w   ...                          s
# 5965            c         b          h   ...                          k
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 771                       w                      w         p          w
# 2889                      w                      g         p          w
# 5089                      n                      p         p          w
# 4729                      n                      n         p          w
# 7396                      w                      p         p          w
# 7343                      p                      w         p          w
# 3221                      p                      g         p          w
# 2697                      b                      p         p          w
# 2360                      w                      w         p          w
# 3780                      p                      g         p          w
# 4816                      n                      b         p          w
# 4849                      n                      n         p          w
# 4329                      w                      w         p          w
# 378                       w                      w         p          w
# 1595                      w                      w         p          w
# 5643                      p                      b         p          w
# 6222                      w                      w         p          w
# 6172                      p                      p         p          w
# 722                       w                      w         p          w
# 3479                      p                      p         p          w
# 1008                      w                      w         p          w
# 6982                      p                      w         p          w
# 5502                      e                      e         p          w
# 3241                      p                      p         p          w
# 7026                      o                      o         p          o
# 6393                      w                      w         p          w
# 6907                      w                      w         p          w
# 3193                      b                      n         p          w
# 3418                      w                      w         p          w
# 3563                      g                      p         p          w
# ...                     ...                    ...       ...        ...
# 2297                      w                      w         p          w
# 6245                      w                      p         p          w
# 4968                      p                      p         p          w
# 4061                      w                      w         p          w
# 2560                      w                      w         p          w
# 3721                      p                      p         p          w
# 4863                      n                      n         p          w
# 6178                      w                      w         p          w
# 4424                      g                      g         p          w
# 7372                      w                      w         p          w
# 4815                      b                      p         p          w
# 2708                      p                      g         p          w
# 2802                      g                      w         p          w
# 3901                      n                      b         p          w
# 7012                      w                      p         p          w
# 6118                      p                      p         p          w
# 3396                      p                      w         p          w
# 2964                      p                      w         p          w
# 4541                      n                      n         p          w
# 6                         w                      w         p          w
# 7649                      w                      w         p          w
# 2156                      p                      g         p          w
# 1236                      w                      w         p          w
# 651                       w                      w         p          w
# 6991                      c                      c         p          w
# 2451                      p                      p         p          w
# 3769                      w                      g         p          w
# 195                       w                      w         p          w
# 4150                      w                      w         p          w
# 5965                      p                      n         p          w
#
#      ring-number ring-type spore-print-color population habitat
# 771            o         p                 n          s       m
# 2889           o         p                 k          v       d
# 5089           o         l                 h          y       p
# 4729           o         l                 h          y       g
# 7396           o         e                 w          v       l
# 7343           o         e                 w          v       d
# 3221           o         p                 n          y       d
# 2697           o         l                 h          y       g
# 2360           o         p                 n          y       d
# 3780           o         p                 n          y       d
# 4816           o         l                 h          v       p
# 4849           o         l                 h          v       d
# 4329           o         e                 w          v       p
# 378            o         p                 n          n       g
# 1595           o         e                 n          a       g
# 5643           o         l                 h          v       g
# 6222           o         e                 w          v       p
# 6172           o         e                 w          v       l
# 722            o         p                 n          v       d
# 3479           o         l                 h          v       p
# 1008           o         e                 n          a       g
# 6982           o         e                 w          v       l
# 5502           t         e                 w          c       w
# 3241           o         p                 k          v       d
# 7026           o         p                 n          c       l
# 6393           o         e                 w          v       d
# 6907           t         p                 w          s       g
# 3193           o         l                 h          v       d
# 3418           o         p                 n          s       d
# 3563           o         p                 n          v       d
# ...          ...       ...               ...        ...     ...
# 2297           o         e                 n          s       g
# 6245           o         e                 w          v       d
# 4968           o         l                 h          v       p
# 4061           o         p                 n          y       d
# 2560           o         p                 k          v       d
# 3721           o         p                 n          v       d
# 4863           o         l                 h          y       p
# 6178           o         e                 w          v       d
# 4424           o         p                 k          y       d
# 7372           t         p                 w          n       g
# 4815           o         l                 h          v       d
# 2708           o         p                 k          y       d
# 2802           o         p                 n          y       d
# 3901           o         l                 h          v       d
# 7012           o         e                 w          v       p
# 6118           o         e                 w          v       l
# 3396           o         p                 n          y       d
# 2964           o         p                 k          y       d
# 4541           o         l                 h          v       g
# 6              o         p                 k          n       m
# 7649           t         p                 w          s       g
# 2156           o         p                 n          y       d
# 1236           o         e                 k          a       g
# 651            o         p                 n          n       m
# 6991           n         n                 w          c       d
# 2451           o         p                 n          y       d
# 3769           o         p                 k          y       d
# 195            o         p                 n          y       u
# 4150           o         p                 n          y       d
# 5965           o         l                 h          v       g
#
# [5687 rows x 23 columns]
#      class cap-shape cap-surface cap-color bruises? odor gill-attachment  \
# 0        p         x           s         n        t    p               f
# 10       e         x           y         y        t    l               f
# 12       e         b           s         y        t    a               f
# 14       e         x           f         n        f    n               f
# 16       e         f           f         w        f    n               f
# 20       e         b           s         y        t    a               f
# 21       p         x           y         n        t    p               f
# 23       e         b           y         w        t    a               f
# 24       e         b           s         w        t    l               f
# 26       e         x           y         y        t    a               f
# 27       e         x           y         w        t    l               f
# 31       p         x           y         w        t    p               f
# 35       e         x           f         y        t    l               f
# 36       e         s           f         g        f    n               f
# 44       e         x           s         y        t    a               f
# 50       e         x           y         n        t    a               f
# 52       e         b           s         w        t    l               f
# 58       e         x           s         y        t    l               f
# 60       e         s           f         g        f    n               f
# 61       e         b           y         y        t    a               f
# 68       e         x           y         y        t    a               f
# 69       e         x           f         g        f    n               f
# 70       e         f           f         y        t    l               f
# 71       e         b           y         w        t    l               f
# 73       e         x           y         n        t    a               f
# 75       e         f           s         y        t    l               f
# 76       e         x           s         w        t    l               f
# 78       p         x           y         n        t    p               f
# 96       e         f           y         n        t    l               f
# 101      e         b           s         y        t    l               f
# ...    ...       ...         ...       ...      ...  ...             ...
# 8051     e         x           f         w        f    n               f
# 8052     e         f           s         n        f    n               a
# 8054     e         x           s         n        f    n               a
# 8061     p         k           s         n        f    s               f
# 8063     e         k           f         w        f    n               f
# 8064     p         k           y         e        f    f               f
# 8065     e         k           s         n        f    n               a
# 8068     e         f           s         n        f    n               a
# 8069     e         k           s         n        f    n               a
# 8071     e         k           s         n        f    n               a
# 8079     p         k           y         e        f    f               f
# 8080     p         k           s         n        f    s               f
# 8086     e         k           s         n        f    n               a
# 8089     p         k           y         e        f    f               f
# 8090     p         k           s         n        f    f               f
# 8092     p         k           y         e        f    y               f
# 8093     p         x           s         n        f    y               f
# 8097     p         k           y         n        f    s               f
# 8099     e         k           f         w        f    n               f
# 8103     e         k           s         n        f    n               a
# 8104     e         k           s         n        f    n               a
# 8105     e         k           s         n        f    n               a
# 8107     e         x           s         n        f    n               a
# 8108     p         k           y         e        f    y               f
# 8109     e         b           s         w        f    n               f
# 8111     e         k           s         w        f    n               f
# 8113     p         k           y         e        f    y               f
# 8116     p         k           y         n        f    s               f
# 8121     e         f           s         n        f    n               a
# 8123     e         x           s         n        f    n               a
#
#      gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0               c         n          k   ...                          s
# 10              c         b          g   ...                          s
# 12              c         b          w   ...                          s
# 14              w         b          n   ...                          f
# 16              w         b          k   ...                          s
# 20              c         b          k   ...                          s
# 21              c         n          n   ...                          s
# 23              c         b          w   ...                          s
# 24              c         b          g   ...                          s
# 26              c         b          n   ...                          s
# 27              c         b          w   ...                          s
# 31              c         n          k   ...                          s
# 35              w         n          w   ...                          s
# 36              c         n          k   ...                          s
# 44              c         b          w   ...                          s
# 50              c         b          w   ...                          y
# 52              c         b          k   ...                          s
# 58              c         b          k   ...                          s
# 60              c         n          k   ...                          s
# 61              c         b          k   ...                          s
# 68              c         b          w   ...                          s
# 69              c         n          p   ...                          s
# 70              w         n          p   ...                          s
# 71              c         b          g   ...                          s
# 73              c         b          p   ...                          y
# 75              w         n          p   ...                          s
# 76              w         n          n   ...                          s
# 78              c         n          w   ...                          s
# 96              c         b          p   ...                          y
# 101             c         b          n   ...                          s
# ...           ...       ...        ...   ...                        ...
# 8051            w         b          w   ...                          k
# 8052            c         b          y   ...                          s
# 8054            c         b          n   ...                          s
# 8061            c         n          b   ...                          k
# 8063            w         b          w   ...                          s
# 8064            c         n          b   ...                          s
# 8065            c         b          y   ...                          s
# 8068            c         b          o   ...                          s
# 8069            c         b          n   ...                          s
# 8071            c         b          n   ...                          s
# 8079            c         n          b   ...                          s
# 8080            c         n          b   ...                          k
# 8086            c         b          n   ...                          s
# 8089            c         n          b   ...                          k
# 8090            c         n          b   ...                          s
# 8092            c         n          b   ...                          s
# 8093            c         n          b   ...                          k
# 8097            c         n          b   ...                          k
# 8099            w         b          w   ...                          k
# 8103            c         b          y   ...                          s
# 8104            c         b          y   ...                          s
# 8105            c         b          y   ...                          s
# 8107            c         b          y   ...                          s
# 8108            c         n          b   ...                          s
# 8109            w         b          w   ...                          s
# 8111            w         b          p   ...                          s
# 8113            c         n          b   ...                          k
# 8116            c         n          b   ...                          k
# 8121            c         b          n   ...                          s
# 8123            c         b          y   ...                          s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 10                        w                      w         p          w
# 12                        w                      w         p          w
# 14                        w                      w         p          w
# 16                        w                      w         p          w
# 20                        w                      w         p          w
# 21                        w                      w         p          w
# 23                        w                      w         p          w
# 24                        w                      w         p          w
# 26                        w                      w         p          w
# 27                        w                      w         p          w
# 31                        w                      w         p          w
# 35                        w                      w         p          w
# 36                        w                      w         p          w
# 44                        w                      w         p          w
# 50                        w                      w         p          w
# 52                        w                      w         p          w
# 58                        w                      w         p          w
# 60                        w                      w         p          w
# 61                        w                      w         p          w
# 68                        w                      w         p          w
# 69                        w                      w         p          w
# 70                        w                      w         p          w
# 71                        w                      w         p          w
# 73                        w                      w         p          w
# 75                        w                      w         p          w
# 76                        w                      w         p          w
# 78                        w                      w         p          w
# 96                        w                      w         p          w
# 101                       w                      w         p          w
# ...                     ...                    ...       ...        ...
# 8051                      w                      w         p          w
# 8052                      o                      o         p          n
# 8054                      o                      o         p          n
# 8061                      p                      p         p          w
# 8063                      w                      w         p          w
# 8064                      p                      p         p          w
# 8065                      o                      o         p          o
# 8068                      o                      o         p          o
# 8069                      o                      o         p          n
# 8071                      o                      o         p          o
# 8079                      w                      w         p          w
# 8080                      p                      w         p          w
# 8086                      o                      o         p          n
# 8089                      w                      p         p          w
# 8090                      p                      p         p          w
# 8092                      p                      p         p          w
# 8093                      w                      w         p          w
# 8097                      p                      p         p          w
# 8099                      w                      w         p          w
# 8103                      o                      o         p          n
# 8104                      o                      o         p          o
# 8105                      o                      o         p          n
# 8107                      o                      o         p          o
# 8108                      p                      w         p          w
# 8109                      w                      w         p          w
# 8111                      w                      w         p          w
# 8113                      p                      p         p          w
# 8116                      p                      w         p          w
# 8121                      o                      o         p          o
# 8123                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 k          s       u
# 10             o         p                 n          n       g
# 12             o         p                 n          s       g
# 14             o         e                 k          a       g
# 16             o         e                 n          a       g
# 20             o         p                 n          s       m
# 21             o         p                 n          v       g
# 23             o         p                 n          n       m
# 24             o         p                 k          s       m
# 26             o         p                 n          n       m
# 27             o         p                 n          n       m
# 31             o         p                 n          s       u
# 35             o         p                 n          v       d
# 36             o         p                 k          v       u
# 44             o         p                 k          n       m
# 50             o         p                 k          s       g
# 52             o         p                 n          n       m
# 58             o         p                 k          n       g
# 60             o         p                 n          v       u
# 61             o         p                 n          s       m
# 68             o         p                 k          n       g
# 69             o         p                 n          v       u
# 70             o         p                 n          v       d
# 71             o         p                 n          s       m
# 73             o         p                 k          s       p
# 75             o         p                 n          v       d
# 76             o         p                 u          v       d
# 78             o         p                 n          v       u
# 96             o         p                 n          s       g
# 101            o         p                 k          n       g
# ...          ...       ...               ...        ...     ...
# 8051           t         p                 w          s       g
# 8052           o         p                 o          v       l
# 8054           o         p                 n          v       l
# 8061           o         e                 w          v       p
# 8063           t         p                 w          s       g
# 8064           o         e                 w          v       l
# 8065           o         p                 b          v       l
# 8068           o         p                 b          c       l
# 8069           o         p                 n          c       l
# 8071           o         p                 y          v       l
# 8079           o         e                 w          v       l
# 8080           o         e                 w          v       d
# 8086           o         p                 o          v       l
# 8089           o         e                 w          v       d
# 8090           o         e                 w          v       d
# 8092           o         e                 w          v       p
# 8093           o         e                 w          v       d
# 8097           o         e                 w          v       l
# 8099           t         p                 w          s       g
# 8103           o         p                 o          c       l
# 8104           o         p                 n          v       l
# 8105           o         p                 y          v       l
# 8107           o         p                 n          c       l
# 8108           o         e                 w          v       l
# 8109           t         p                 w          n       g
# 8111           t         p                 w          n       g
# 8113           o         e                 w          v       d
# 8116           o         e                 w          v       l
# 8121           o         p                 b          c       l
# 8123           o         p                 o          c       l
#
# [2437 rows x 23 columns]

# %%
def entropy(x):
    result = 0
    unique = list(set(x))
    for i in unique:
        p = x.count(i)/len(x)
        result += -(p)*log2(p)
    return result

# %%
results = [False, False, True, True, True, False, True, False, True, True, True, True, True, False]
entropy(results)
# Out:
# 0.9402859586706311

# %%
def gain(classification, x):
    zipped = list(zip(classification, x))
    result = entropy(classification)
    unique = list(set(x))
    for i in unique:
        sublist = [y for y in zipped if y[1]==i]
        p = x.count(i)/len(x)
        result += -(p)*entropy(sublist)
    return result

# %%
weak = "Weak"
strong = "Strong"
wind = [weak, strong, weak, weak, weak, strong, strong, weak, weak, weak, strong, strong, weak, strong]
gain(results, wind)
# Out:
# 0.048127030408269544

# %%
def splitInfo(classification, x):
    result = 0
    unique = list(set(x))
    for i in unique:
        p = x.count(i)/len(x)
        result += -(p)*log2(p)
    return result

# %%
splitInfo(results, wind)
# Out:
# 0.9852281360342515

# %%
def gainRatio(classification, x):
    if (gain(classification, x) == 0) or (splitInfo(classification, x) == 0):
        return 0
    else:
        return gain(classification, x) / splitInfo(classification, x)

# %%
gainRatio(results, wind)
# Out:
# 0.04884861551152088

# %%
sunny = "Sunny"
overcast = "Overcast"
rain = "Rain"
outlook = [sunny, sunny, overcast, rain, rain, rain, overcast, sunny, sunny, rain, sunny, overcast, overcast, rain]
gainRatio(results, outlook)
# Out:
# 0.15642756242117528

# %%
class Tree:
    def __init__(self, df):
        self.dfFull = df
        self.results = list(df['class'])
        self.df = df.drop(columns=['class'])
        self.best = self.bestAttr()
        self.total = ""
        if self.best == "":
            self.nodes = {}
            self.total = str(list(set(list(self.dfFull['class'])))[0])
            return
        bestCol = list(df[self.best])
        bestColValues = list(set(bestCol))
        self.nodes = dict.fromkeys(bestColValues)
        self.buildNodes()
            
    def buildNodes(self):
         for i in self.nodes:
            qr = (str(self.best) + " == " + str(i))
            dfSplit = self.dfFull.loc[self.dfFull[self.best] == i]
            self.nodes[i] = Tree(dfSplit)
        
    def bestAttr(self):
        maxGain = 0
        whoIsMaxGain = ""
        for i in self.df.columns:
            gain = gainRatio(self.results, list(self.df[i]))
            if gain > maxGain:
                maxGain = gain
                whoIsMaxGain = i
        return whoIsMaxGain
    
    def getClassification(self, x):
        if self.best != "":
            return self.nodes[x[self.best]].getClassification(x)
        else:
            return self.total
    
    def __str__(self, level=0):
        ret = "\t"*level+(self.best)+"\n"
        for child in self.nodes:
            ret += "\t"*level+child + ": " + self.total + self.nodes[child].total + self.nodes[child].__str__(level+1)
        return ret

# %%
decisionTree = Tree(trainingSample)

print("FOR DEVELOPER TEST ONLY, FORMATTING IS NOT WORKING CORRECTLY")
print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
print(decisionTree)
print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
print("FOR DEVELOPER TEST ONLY, FORMATTING IS NOT WORKING CORRECTLY")
# Out:
# FOR DEVELOPER TEST ONLY, FORMATTING IS NOT WORKING CORRECTLY
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# odor
# l: e
# s: p
# n: 	spore-print-color
# 	h: e
# 	n: e
# 	y: e
# 	k: e
# 	w: 		veil-color
# 		w: 			gill-size
# 			n: 				gill-spacing
# 				w: 					bruises?
# 					f: e
# 					t: p
# 				c: p
# 			b: e
# 		y: p
# 	r: p
# 	o: e
# 	b: e
# y: p
# m: p
# c: p
# p: p
# f: p
# a: e
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# FOR DEVELOPER TEST ONLY, FORMATTING IS NOT WORKING CORRECTLY

# %%
predictions = []
for i in testingSample.index.values:
    predictions.append(tuple([testingSample.loc[i]['class'], decisionTree.getClassification(testingSample.loc[i])]))
print(predictions)
# Out:
# [('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('p', 'p'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p', 'p'), ('e', 'e'), ('e', 'e'), ('e', 'e'), ('p ...

# %%
def hit(x):
    if x[0] == x[1]:
        return True
    else:
        return False

# %%
hits = list(filter(hit, predictions))

numPredictions = len(predictions)
numHits = len(hits)

performance = numHits/numPredictions

# %%
print("Correctly Classified Rows: " + str(performance*100) + "%")
print("Incorrectly Classified Rows: " + str(100-(performance*100)) + "%")
# Out:
# Correctly Classified Rows: 100.0%
# Incorrectly Classified Rows: 0.0%
